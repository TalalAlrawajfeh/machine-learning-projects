# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.python.keras import Input, Model
from tensorflow.python.keras.layers import Conv2D, BatchNormalization, ReLU, AveragePooling2D, \
    Dense, Concatenate, MaxPooling2D, Flatten


def conv_block(input_layer,
               filters,
               kernel_size):
    output_layer = Conv2D(filters=filters,
                          kernel_size=kernel_size,
                          padding='same',
                          use_bias=False,
                          kernel_initializer='he_normal')(input_layer)
    output_layer = BatchNormalization()(output_layer)
    return ReLU()(output_layer)


def inception_module(input_layer,
                     filters1x1,
                     filters3x3,
                     filters5x5):
    conv1x1 = conv_block(input_layer, filters1x1, (1, 1))

    conv3x3 = conv_block(input_layer, int(filters3x3 * 2 / 3), (1, 1))
    conv3x3 = conv_block(conv3x3, filters3x3, (3, 3))

    conv5x5 = conv_block(input_layer, int(filters5x5 * 3 / 4), (1, 1))
    conv5x5 = conv_block(conv5x5, filters5x5, (5, 5))

    pooling = AveragePooling2D(pool_size=(3, 3),
                               strides=(1, 1),
                               padding='same')(input_layer)
    pooling = conv_block(pooling, filters1x1, (1, 1))

    return Concatenate()([conv1x1, conv3x3, conv5x5, pooling])


def reduced_inception():
    input_layer = Input(shape=(28, 28, 1))

    output_layer = conv_block(input_layer, 16, (3, 3))
    output_layer = conv_block(output_layer, 16, (3, 3))
    output_layer = MaxPooling2D(pool_size=(3, 3),
                                strides=(2, 2))(output_layer)

    output_layer = inception_module(output_layer, 16, 32, 16)
    output_layer = inception_module(output_layer, 32, 64, 32)
    output_layer = MaxPooling2D(pool_size=(3, 3),
                                strides=(2, 2))(output_layer)

    output_layer = inception_module(output_layer, 32, 64, 32)
    output_layer = inception_module(output_layer, 64, 128, 64)
    output_layer = MaxPooling2D(pool_size=(3, 3),
                                strides=(2, 2))(output_layer)

    output_layer = conv_block(output_layer, 128, (1, 1))
    embedding = Flatten()(output_layer)

    predictions = Dense(units=128,
                        kernel_initializer='he_normal',
                        use_bias=False)(embedding)
    predictions = BatchNormalization()(predictions)
    predictions = ReLU()(predictions)

    predictions = Dense(units=10,
                        kernel_initializer='glorot_normal',
                        activation='softmax')(predictions)

    return Model(inputs=input_layer, outputs=predictions)


def pre_process(image):
    return (image / 127.5 - 1.0).reshape(28, 28, 1)


def to_one_hot_encoding(label):
    encoding = [0.0] * 10
    encoding[label] = 1.0
    return encoding

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = [pre_process(image) for image in train_images]
test_images = [pre_process(image) for image in test_images]

train_labels = [to_one_hot_encoding(label) for label in train_labels]
test_labels = [to_one_hot_encoding(label) for label in test_labels]

model = reduced_inception()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 16)   144         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 28, 28, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 16)   2304        re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 28, 28, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 13, 13, 16)   0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 13, 13, 21)   336         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 13, 13, 12)   192         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 13, 13, 21)   84          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 13, 13, 12)   48          conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 13, 13, 21)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 13, 13, 12)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 13, 13, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 13, 13, 16)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 13, 13, 32)   6048        re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 13, 13, 16)   4800        re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 13, 13, 16)   256         average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 13, 13, 16)   64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 13, 13, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 13, 13, 16)   64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 13, 13, 16)   64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 13, 13, 16)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 13, 13, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 13, 13, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 13, 13, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 13, 13, 80)   0           re_lu_16[0][0]
#                                                                  re_lu_18[0][0]
#                                                                  re_lu_20[0][0]
#                                                                  re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 13, 13, 42)   3360        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 13, 13, 24)   1920        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 13, 13, 42)   168         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 13, 13, 24)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 13, 13, 42)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 13, 13, 24)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 13, 13, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 13, 13, 32)   2560        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 13, 13, 64)   24192       re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 13, 13, 32)   19200       re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 13, 13, 32)   2560        average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 13, 13, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 13, 13, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 13, 13, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 13, 13, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 13, 13, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 13, 13, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 13, 13, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 13, 13, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 13, 13, 160)  0           re_lu_22[0][0]
#                                                                  re_lu_24[0][0]
#                                                                  re_lu_26[0][0]
#                                                                  re_lu_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 160)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 6, 6, 42)     6720        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 6, 6, 24)     3840        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 6, 6, 42)     168         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 6, 6, 24)     96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 6, 6, 42)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 6, 6, 24)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 6, 6, 160)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 6, 6, 32)     5120        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 6, 6, 64)     24192       re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 6, 6, 32)     19200       re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 6, 6, 32)     5120        average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 6, 6, 32)     128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 6, 6, 64)     256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 6, 6, 32)     128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 6, 6, 32)     128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 6, 6, 32)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 6, 6, 64)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 6, 6, 32)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 6, 6, 32)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 6, 6, 160)    0           re_lu_28[0][0]
#                                                                  re_lu_30[0][0]
#                                                                  re_lu_32[0][0]
#                                                                  re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 6, 6, 85)     13600       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 6, 6, 48)     7680        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 6, 6, 85)     340         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 6, 6, 48)     192         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 6, 6, 85)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 6, 6, 48)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 6, 6, 160)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 6, 6, 64)     10240       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 6, 6, 128)    97920       re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 6, 6, 64)     76800       re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 6, 6, 64)     10240       average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 6, 6, 64)     256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 6, 6, 128)    512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 6, 6, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 6, 6, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 6, 6, 64)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 6, 6, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 6, 6, 64)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 6, 6, 64)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 6, 6, 320)    0           re_lu_34[0][0]
#                                                                  re_lu_36[0][0]
#                                                                  re_lu_38[0][0]
#                                                                  re_lu_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 320)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 2, 2, 128)    40960       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 2, 2, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 2, 2, 128)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           re_lu_40[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          65536       flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 128)          512         dense_1[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 128)          0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1290        re_lu_41[0][0]
# ==================================================================================================
# Total params: 461,810
# Trainable params: 459,198
# Non-trainable params: 2,612
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=[tf.keras.metrics.categorical_accuracy])

model.fit(x=np.array(train_images),
          y=np.array(train_labels),
          validation_data=(np.array(test_images),
                          np.array(test_labels)),
          batch_size=128,
          validation_batch_size=1024,
          epochs=20)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 15s 26ms/step - loss: 0.2962 - categorical_accuracy: 0.9110 - val_loss: 0.0537 - val_categorical_accuracy: 0.9825
# Epoch 2/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0284 - categorical_accuracy: 0.9914 - val_loss: 0.0418 - val_categorical_accuracy: 0.9866
# Epoch 3/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0197 - categorical_accuracy: 0.9939 - val_loss: 0.0455 - val_categorical_accuracy: 0.9859
# Epoch 4/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0170 - categorical_accuracy: 0.9948 - val_loss: 0.0287 - val_categorical_accuracy: 0.9902
# Epoch 5/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0132 - categorical_accuracy: 0.9959 - val_loss: 0.0471 - val_categorical_accuracy: 0.9846
# Epoch 6/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0112 - categorical_accuracy: 0.9965 - val_loss: 0.0277 - val_categorical_accuracy: 0.9926
# Epoch 7/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0086 - categorical_accuracy: 0.9969 - val_loss: 0.0502 - val_categorical_accuracy: 0.9830
# Epoch 8/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0088 - categorical_accuracy: 0.9971 - val_loss: 0.0305 - val_categorical_accuracy: 0.9916
# Epoch 9/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0085 - categorical_accuracy: 0.9969 - val_loss: 0.0772 - val_categorical_accuracy: 0.9785
# Epoch 10/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0088 - categorical_accuracy: 0.9969 - val_loss: 0.0252 - val_categorical_accuracy: 0.9929
# Epoch 11/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0069 - categorical_accuracy: 0.9977 - val_loss: 0.0386 - val_categorical_accuracy: 0.9894
# Epoch 12/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0072 - categorical_accuracy: 0.9976 - val_loss: 0.0405 - val_categorical_accuracy: 0.9884
# Epoch 13/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0062 - categorical_accuracy: 0.9980 - val_loss: 0.0207 - val_categorical_accuracy: 0.9928
# Epoch 14/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0044 - categorical_accuracy: 0.9986 - val_loss: 0.0225 - val_categorical_accuracy: 0.9933
# Epoch 15/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0039 - categorical_accuracy: 0.9988 - val_loss: 0.0316 - val_categorical_accuracy: 0.9922
# Epoch 16/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0043 - categorical_accuracy: 0.9987 - val_loss: 0.0448 - val_categorical_accuracy: 0.9888
# Epoch 17/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0060 - categorical_accuracy: 0.9982 - val_loss: 0.0334 - val_categorical_accuracy: 0.9915
# Epoch 18/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0038 - categorical_accuracy: 0.9988 - val_loss: 0.0214 - val_categorical_accuracy: 0.9936
# Epoch 19/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0038 - categorical_accuracy: 0.9988 - val_loss: 0.0312 - val_categorical_accuracy: 0.9906
# Epoch 20/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0030 - categorical_accuracy: 0.9990 - val_loss: 0.0600 - val_categorical_accuracy: 0.9851

# %%
from matplotlib import pyplot as plt

image = (train_images[0] + 1.0) * 127.5
image = image.reshape(28, 28).astype(np.uint8)

plt.imshow(image, plt.cm.gray)
plt.show()

predicted_label = np.argmax(model.predict(np.array([train_images[0]]))[0])
true_label = np.argmax(train_labels[0])

print(f'predicted label: {predicted_label}')
print(f'true label: {true_label}')
# Out:
# predicted label: 5
# true label: 5
